# %% [markdown]
# # Welcome to A120 -Optical and IR lab

# %% [markdown]
# In this class we will be performing a variety of astronomical tasks, from observations to data reduction and analysis. These tasks will require us to be familiar with UNIX based filesystems (such as those on the lab computers running Ubuntu Linux, or Mac computers), and will require us to become comfortable writing scripts and routines in Python (or, if you insist, IDL). A note, Malena and I will be doing our tutorials in python, and are mostly well versed in Python. If you choose to write in IDL, we won't be of much help, but Gaspard knows IDL and may be of some assistance. He will not be as readily available.

# %%
pwd
# Out:
# u'/Users/ipasha/anaconda2/bin'

# %% [markdown]
# The above command (which can be used in unix or in ipython (specifically, which is why it works here), demonstrates where you are in a filesystem, if you ever get lost.

# %%
ls
# Out:
# 2to3*
# Assistant-qt4.app/
# Designer-qt4.app/
# Linguist-qt4.app/
# QMLViewer-qt4.app/
# Untitled.ipynb
# activate*
# activate-global-python-argcomplete*
# anaconda*
# anaconda-navigator*
# asadmin*
# binstar*
# blaze-server*
# bokeh*
# bokeh-server*
# bundle_image*
# c_rehash*
# cfadmin*
# conda*
# conda-build*
# conda-convert*
# conda-develop*
# conda-env*
# conda-index*
# conda-inspect*
# conda-metapackage*
# conda-pipbuild*
# conda-render*
# conda-server*
# conda-sign*
# conda-skeleton*
# cq*
# curl*
# curl-config*
# cwutil*
# cygdb*
# cython*
# cythonize*
# deactivate*
# dynamodb_dump*
# dynamodb_load*
# easy_install*
# easy_install-2.7@
# elbadmin*
# f2py*
# fetch_file*
# fits2bitmap*
# fitscheck*
# fitsdiff*
# fitsheader*
# fitsinfo*
# flask*
# freetype-config*
# get_objgraph.py*
# gif2h5*
# glacier*
# grin*
# grind*
# h52gif*
# h5c++*
# h5cc*
# h5copy*
# h5debug*
# h5diff*
# h5dump*
# h5import*
# h5jam*
# h5ls*
# h5mkgrp*
# h5perf_serial*
# h5redeploy*
# h5repack*
# h5repart*
# h5stat*
# h5unjam*
# idle*
# instance_events*
# iptest*
# iptest2*
# ipython*
# ipython2*
# isympy*
# jsonschema*
# jupyter*
# jupyter-console*
# jupyter-kernelspec*
# jupyter-migrate*
# jupyter-nbconvert*
# jupyter-nbextension*
# jupyter-notebook*
# jupyter-qtconsole*
# jupyter-serverextension*
# jupyter-trust*
# jupyter_mac.command*
# kill_instance*
# launch_instance*
# lconvert-qt4*
# libdynd-config*
# libpng-config@
# libpng16-config*
# list_instances*
# lrelease-qt4*
# lss3*
# lupdate-qt4*
# macdeployqt-qt4*
# moc-qt4*
# mturk*
# nbpresent*
# nosetests*
# numba*
# odo*
# openssl*
# pep8*
# pip*
# pixeltool-qt4.app/
# png-fix-itxt*
# pngfix*
# pt2to3*
# ptdump*
# ptrepack*
# pttree*
# py.test*
# pyami_sendmail*
# pybabel*
# pycc*
# pydoc*
# pyflakes*
# pygmentize*
# pylupdate4*
# pyrcc4*
# python@
# python-argcomplete-check-easy-install-script*
# python-config@
# python.app*
# python2@
# python2-config@
# python2.7*
# python2.7-config*
# pythonw*
# pyuic4*
# qcollectiongenerator-qt4*
# qdoc3-qt4*
# qhelpconverter-qt4.app/
# qhelpgenerator-qt4*
# qmake-qt4*
# qmlplugindump-qt4*
# qt.conf
# qt3to4-qt4*
# qttracereplay-qt4.app/
# rcc-qt4*
# redis-benchmark*
# redis-check-aof*
# redis-check-rdb*
# redis-cli*
# redis-sentinel@
# redis-server*
# register-python-argcomplete*
# route53*
# rst2html.py*
# rst2latex.py*
# rst2man.py*
# rst2odt.py*
# rst2odt_prepstyles.py*
# rst2pseudoxml.py*
# rst2s5.py*
# rst2xetex.py*
# rst2xml.py*
# rstpep2html.py*
# runxlrd.py*
# s3put*
# samp_hub*
# sdbadmin*
# sip*
# skivi*
# smtpd.py*
# sphinx-apidoc*
# sphinx-autogen*
# sphinx-build*
# sphinx-quickstart*
# spyder*
# sqlite3*
# taskadmin*
# tclsh8.5*
# test_libdynd*
# uic-qt4*
# unpickle.py*
# unxz@
# vba_extract.py*
# volint*
# wcslint*
# wheel*
# wish8.5*
# xlwings*
# xml2-config*
# xmlcatalog*
# xmllint*
# xmlpatterns-qt4*
# xmlpatternsvalidator-qt4*
# xslt-config*
# xsltproc*
# xz*

# %% [markdown]
# The "ls" command will show you the contents of the directory you are in. It has several flags (or optional arguments) which can be used to tailor the commands to your needs. For example, "ls -a" will list all files, including hidden ones, "ls -ltr" will show the files and when they were created, by whom, and permissions

# %%
ls -ltr
# Out:
# total 69496
# -rwxr-xr-x  2 ipasha  staff    24256 Jan 23  2014 xsltproc*
# -rwxr-xr-x  2 ipasha  staff    25160 Mar 16  2015 wish8.5*
# -rwxr-xr-x  2 ipasha  staff    12712 Mar 16  2015 tclsh8.5*
# -rwxr-xr-x  2 ipasha  staff    69600 Jun 30  2015 xmllint*
# -rwxr-xr-x  2 ipasha  staff    18480 Jun 30  2015 xmlcatalog*
# -rwxr-xr-x  2 ipasha  staff   324204 Oct  8  2015 sip*
# -rwxr-xr-x  2 ipasha  staff  6063088 Mar 16 15:40 test_libdynd*
# -rwxr-xr-x  2 ipasha  staff     1209 Mar 16 15:40 libdynd-config*
# -rwxr-xr-x  2 ipasha  staff   100720 Apr  1 19:39 xz*
# -rwxr-xr-x  2 ipasha  staff     6109 Apr  4 14:21 h5redeploy*
# -rwxr-xr-x  2 ipasha  staff   120220 Apr  4 14:21 h5unjam*
# -rwxr-xr-x  2 ipasha  staff   132908 Apr  4 14:21 h5stat*
# -rwxr-xr-x  2 ipasha  staff    14648 Apr  4 14:21 h5repart*
# -rwxr-xr-x  2 ipasha  staff   178396 Apr  4 14:21 h5repack*
# -rwxr-xr-x  2 ipasha  staff   155604 Apr  4 14:21 h5perf_serial*
# -rwxr-xr-x  2 ipasha  staff   119936 Apr  4 14:21 h5mkgrp*
# -rwxr-xr-x  2 ipasha  staff   144432 Apr  4 14:21 h5ls*
# -rwxr-xr-x  2 ipasha  staff   120492 Apr  4 14:21 h5jam*
# -rwxr-xr-x  2 ipasha  staff   166344 Apr  4 14:21 h5import*
# -rwxr-xr-x  2 ipasha  staff   215696 Apr  4 14:21 h5dump*
# -rwxr-xr-x  2 ipasha  staff   203992 Apr  4 14:21 h5diff*
# -rwxr-xr-x  2 ipasha  staff    15552 Apr  4 14:21 h5debug*
# -rwxr-xr-x  2 ipasha  staff   120164 Apr  4 14:21 h5copy*
# -rwxr-xr-x  2 ipasha  staff   120532 Apr  4 14:21 h52gif*
# -rwxr-xr-x  2 ipasha  staff   126308 Apr  4 14:21 gif2h5*
# -rwxr-xr-x  2 ipasha  staff   172828 May 24 10:49 curl*
# -rwxr-xr-x  2 ipasha  staff  1432944 May 25 15:33 sqlite3*
# -rwxr-xr-x  2 ipasha  staff   560428 May 31 14:36 openssl*
# -rwxr-xr-x  2 ipasha  staff    64104 Jun  2 15:13 pngfix*
# -rwxr-xr-x  2 ipasha  staff     8916 Jun  2 15:13 png-fix-itxt*
# -rwxr-xr-x  2 ipasha  staff    14928 Jun  5 19:49 redis-check-aof*
# -rwxr-xr-x  2 ipasha  staff   100708 Jun  5 19:49 redis-benchmark*
# -rwxr-xr-x  2 ipasha  staff  1095168 Jun  5 19:49 redis-server*
# -rwxr-xr-x  2 ipasha  staff   167632 Jun  5 19:49 redis-cli*
# -rwxr-xr-x  2 ipasha  staff  1095168 Jun  5 19:49 redis-check-rdb*
# -rwxr-xr-x  2 ipasha  staff       41 Jun  7 11:25 jupyter_mac.command*
# -rwxr-xr-x  2 ipasha  staff   348492 Jun 14 18:31 lconvert-qt4*
# -rwxr-xr-x  2 ipasha  staff  1173180 Jun 14 18:31 lupdate-qt4*
# -rwxr-xr-x  2 ipasha  staff  2054400 Jun 14 18:31 lrelease-qt4*
# -rwxr-xr-x  2 ipasha  staff   117380 Jun 14 18:31 macdeployqt-qt4*
# -rwxr-xr-x  2 ipasha  staff  1420816 Jun 14 18:31 moc-qt4*
# -rwxr-xr-x  2 ipasha  staff  2165032 Jun 14 18:31 qdoc3-qt4*
# -rwxr-xr-x  2 ipasha  staff   101520 Jun 14 18:31 qcollectiongenerator-qt4*
# -rwxr-xr-x  2 ipasha  staff  8432816 Jun 14 18:31 qmake-qt4*
# -rwxr-xr-x  2 ipasha  staff    38128 Jun 14 18:31 qhelpgenerator-qt4*
# -rwxr-xr-x  2 ipasha  staff  1173244 Jun 14 18:31 qt3to4-qt4*
# -rwxr-xr-x  2 ipasha  staff   118704 Jun 14 18:31 qmlplugindump-qt4*
# -rwxr-xr-x  2 ipasha  staff  1619164 Jun 14 18:31 rcc-qt4*
# -rwxr-xr-x  2 ipasha  staff  2219316 Jun 14 18:31 uic-qt4*
# -rwxr-xr-x  2 ipasha  staff    23292 Jun 14 18:31 xmlpatternsvalidator-qt4*
# -rwxr-xr-x  2 ipasha  staff    96268 Jun 14 18:31 xmlpatterns-qt4*
# -rwxr-xr-x  2 ipasha  staff   240316 Jun 15 09:49 pylupdate4*
# -rwxr-xr-x  2 ipasha  staff    76224 Jun 15 09:49 pyrcc4*
# -rwxr-xr-x  2 ipasha  staff     2231 Jul  1 12:00 deactivate*
# -rwxr-xr-x  2 ipasha  staff     3251 Jul  1 12:00 activate*
# -rwxr-xr-x  1 ipasha  staff     8984 Jul  2 15:44 python2.7*
# -rwxr-xr-x  1 ipasha  staff      152 Aug 22 17:18 wcslint*
# -rwxr-xr-x  1 ipasha  staff      164 Aug 22 17:18 volint*
# -rwxr-xr-x  1 ipasha  staff      172 Aug 22 17:18 samp_hub*
# -rwxr-xr-x  1 ipasha  staff      239 Aug 22 17:18 register-python-argcomplete*
# -rwxr-xr-x  1 ipasha  staff      273 Aug 22 17:18 python-argcomplete-check-easy-install-script*
# -rwxr-xr-x  1 ipasha  staff      322 Aug 22 17:18 fitsinfo*
# -rwxr-xr-x  1 ipasha  staff      182 Aug 22 17:18 fitsheader*
# -rwxr-xr-x  1 ipasha  staff      178 Aug 22 17:18 fitsdiff*
# -rwxr-xr-x  1 ipasha  staff      180 Aug 22 17:18 fitscheck*
# -rwxr-xr-x  1 ipasha  staff      196 Aug 22 17:18 fits2bitmap*
# -rwxr-xr-x  1 ipasha  staff      166 Aug 22 17:18 conda-server*
# -rwxr-xr-x  1 ipasha  staff      166 Aug 22 17:18 binstar*
# -rwxr-xr-x  1 ipasha  staff      168 Aug 22 17:18 anaconda-navigator*
# -rwxr-xr-x  1 ipasha  staff      166 Aug 22 17:18 anaconda*
# -rwxr-xr-x  1 ipasha  staff      253 Aug 22 17:18 activate-global-python-argcomplete*
# -rwxr-xr-x  1 ipasha  staff     3785 Aug 22 17:18 taskadmin*
# -rwxr-xr-x  1 ipasha  staff     7011 Aug 22 17:18 sdbadmin*
# -rwxr-xr-x  1 ipasha  staff    16855 Aug 22 17:18 s3put*
# -rwxr-xr-x  1 ipasha  staff     9050 Aug 22 17:18 route53*
# -rwxr-xr-x  1 ipasha  staff      160 Aug 22 17:18 pybabel*
# -rwxr-xr-x  1 ipasha  staff     2633 Aug 22 17:18 pyami_sendmail*
# -rwxr-xr-x  1 ipasha  staff    19164 Aug 22 17:18 mturk*
# -rwxr-xr-x  1 ipasha  staff     3460 Aug 22 17:18 lss3*
# -rwxr-xr-x  1 ipasha  staff     3114 Aug 22 17:18 list_instances*
# -rwxr-xr-x  1 ipasha  staff    10621 Aug 22 17:18 launch_instance*
# -rwxr-xr-x  1 ipasha  staff      940 Aug 22 17:18 kill_instance*
# -rwxr-xr-x  1 ipasha  staff     5794 Aug 22 17:18 instance_events*
# -rwxr-xr-x  1 ipasha  staff     5262 Aug 22 17:18 glacier*
# -rwxr-xr-x  1 ipasha  staff     1889 Aug 22 17:18 fetch_file*
# -rwxr-xr-x  1 ipasha  staff     9709 Aug 22 17:18 elbadmin*
# -rwxr-xr-x  1 ipasha  staff     3519 Aug 22 17:18 dynamodb_load*
# -rwxr-xr-x  1 ipasha  staff     2149 Aug 22 17:18 dynamodb_dump*
# -rwxr-xr-x  1 ipasha  staff      158 Aug 22 17:18 cythonize*
# -rwxr-xr-x  1 ipasha  staff      165 Aug 22 17:18 cython*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 cygdb*
# -rwxr-xr-x  1 ipasha  staff     5061 Aug 22 17:18 cwutil*
# -rwxr-xr-x  1 ipasha  staff     5236 Aug 22 17:18 curl-config*
# -rwxr-xr-x  1 ipasha  staff     3069 Aug 22 17:18 cq*
# -rwxr-xr-x  1 ipasha  staff      109 Aug 22 17:18 conda-skeleton*
# -rwxr-xr-x  1 ipasha  staff      105 Aug 22 17:18 conda-sign*
# -rwxr-xr-x  1 ipasha  staff      107 Aug 22 17:18 conda-render*
# -rwxr-xr-x  1 ipasha  staff      109 Aug 22 17:18 conda-pipbuild*
# -rwxr-xr-x  1 ipasha  staff      112 Aug 22 17:18 conda-metapackage*
# -rwxr-xr-x  1 ipasha  staff      108 Aug 22 17:18 conda-inspect*
# -rwxr-xr-x  1 ipasha  staff      106 Aug 22 17:18 conda-index*
# -rwxr-xr-x  1 ipasha  staff      150 Aug 22 17:18 conda-env*
# -rwxr-xr-x  1 ipasha  staff      108 Aug 22 17:18 conda-develop*
# -rwxr-xr-x  1 ipasha  staff      108 Aug 22 17:18 conda-convert*
# -rwxr-xr-x  1 ipasha  staff      106 Aug 22 17:18 conda-build*
# -rwxr-xr-x  1 ipasha  staff      137 Aug 22 17:18 conda*
# -rwxr-xr-x  1 ipasha  staff     3460 Aug 22 17:18 cfadmin*
# -rwxr-xr-x  1 ipasha  staff     1570 Aug 22 17:18 bundle_image*
# -rwxr-xr-x  1 ipasha  staff      254 Aug 22 17:18 bokeh-server*
# -rwxr-xr-x  1 ipasha  staff      107 Aug 22 17:18 bokeh*
# -rwxr-xr-x  1 ipasha  staff      153 Aug 22 17:18 blaze-server*
# -rwxr-xr-x  1 ipasha  staff    12004 Aug 22 17:18 asadmin*
# -rwxr-xr-x  1 ipasha  staff     2456 Aug 22 17:18 xslt-config*
# -rwxr-xr-x  1 ipasha  staff     1667 Aug 22 17:18 xml2-config*
# -rwxr-xr-x  1 ipasha  staff      426 Aug 22 17:18 unpickle.py*
# -rwxr-xr-x  1 ipasha  staff      688 Aug 22 17:18 rstpep2html.py*
# -rwxr-xr-x  1 ipasha  staff      620 Aug 22 17:18 rst2xml.py*
# -rwxr-xr-x  1 ipasha  staff      804 Aug 22 17:18 rst2xetex.py*
# -rwxr-xr-x  1 ipasha  staff      655 Aug 22 17:18 rst2s5.py*
# -rwxr-xr-x  1 ipasha  staff      619 Aug 22 17:18 rst2pseudoxml.py*
# -rwxr-xr-x  1 ipasha  staff     1716 Aug 22 17:18 rst2odt_prepstyles.py*
# -rwxr-xr-x  1 ipasha  staff      782 Aug 22 17:18 rst2odt.py*
# -rwxr-xr-x  1 ipasha  staff      618 Aug 22 17:18 rst2man.py*
# -rwxr-xr-x  1 ipasha  staff      809 Aug 22 17:18 rst2latex.py*
# -rwxr-xr-x  1 ipasha  staff      612 Aug 22 17:18 rst2html.py*
# -rwxr-xr-x  1 ipasha  staff     2332 Aug 22 17:18 libpng16-config*
# lrwxr-xr-x  1 ipasha  staff       15 Aug 22 17:18 libpng-config@ -> libpng16-config
# -rwxr-xr-x  1 ipasha  staff      163 Aug 22 17:18 jupyter-migrate*
# -rwxr-xr-x  1 ipasha  staff      180 Aug 22 17:18 jupyter-kernelspec*
# -rwxr-xr-x  1 ipasha  staff      112 Aug 22 17:18 jupyter-console*
# -rwxr-xr-x  1 ipasha  staff      153 Aug 22 17:18 jupyter*
# -rwxr-xr-x  1 ipasha  staff      142 Aug 22 17:18 jsonschema*
# -rwxr-xr-x  1 ipasha  staff      151 Aug 22 17:18 ipython2*
# -rwxr-xr-x  1 ipasha  staff      151 Aug 22 17:18 ipython*
# -rwxr-xr-x  1 ipasha  staff      197 Aug 22 17:18 iptest2*
# -rwxr-xr-x  1 ipasha  staff      197 Aug 22 17:18 iptest*
# -rwxr-xr-x  1 ipasha  staff    13354 Aug 22 17:18 h5cc*
# -rwxr-xr-x  1 ipasha  staff    13149 Aug 22 17:18 h5c++*
# -rwxr-xr-x  1 ipasha  staff      128 Aug 22 17:18 grind*
# -rwxr-xr-x  1 ipasha  staff      127 Aug 22 17:18 grin*
# -rwxr-xr-x  1 ipasha  staff     1200 Aug 22 17:18 get_objgraph.py*
# -rwxr-xr-x  1 ipasha  staff     3842 Aug 22 17:18 freetype-config*
# -rwxr-xr-x  1 ipasha  staff      132 Aug 22 17:18 flask*
# -rwxr-xr-x  1 ipasha  staff      126 Aug 22 17:18 nosetests*
# -rwxr-xr-x  1 ipasha  staff      330 Aug 22 17:18 nbpresent*
# -rwxr-xr-x  1 ipasha  staff      175 Aug 22 17:18 jupyter-trust*
# -rwxr-xr-x  1 ipasha  staff      164 Aug 22 17:18 jupyter-serverextension*
# -rwxr-xr-x  1 ipasha  staff      154 Aug 22 17:18 jupyter-notebook*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 jupyter-nbextension*
# -rwxr-xr-x  1 ipasha  staff      117 Aug 22 17:18 jupyter-nbconvert*
# -rwxr-xr-x  1 ipasha  staff      134 Aug 22 17:18 pycc*
# -rwxr-xr-x  1 ipasha  staff      120 Aug 22 17:18 pip*
# -rwxr-xr-x  1 ipasha  staff      123 Aug 22 17:18 pep8*
# -rwxr-xr-x  1 ipasha  staff      785 Aug 22 17:18 odo*
# -rwxr-xr-x  1 ipasha  staff      148 Aug 22 17:18 numba*
# -rwxr-xr-x  1 ipasha  staff      776 Aug 22 17:18 f2py*
# -rwxr-xr-x  1 ipasha  staff     5126 Aug 22 17:18 c_rehash*
# -rwxr-xr-x  1 ipasha  staff    18557 Aug 22 17:18 smtpd.py*
# -rwxr-xr-x  1 ipasha  staff      107 Aug 22 17:18 pyuic4*
# -rwxr-xr-x  1 ipasha  staff      133 Aug 22 17:18 pythonw*
# -rwxr-xr-x  1 ipasha  staff     1697 Aug 22 17:18 python2.7-config*
# lrwxr-xr-x  1 ipasha  staff       16 Aug 22 17:18 python2-config@ -> python2.7-config
# lrwxr-xr-x  1 ipasha  staff        9 Aug 22 17:18 python2@ -> python2.7
# -rwxr-xr-x  1 ipasha  staff      133 Aug 22 17:18 python.app*
# lrwxr-xr-x  1 ipasha  staff       16 Aug 22 17:18 python-config@ -> python2.7-config
# lrwxr-xr-x  1 ipasha  staff        9 Aug 22 17:18 python@ -> python2.7
# -rwxr-xr-x  1 ipasha  staff      146 Aug 22 17:18 pygmentize*
# -rwxr-xr-x  1 ipasha  staff      138 Aug 22 17:18 pyflakes*
# -rwxr-xr-x  1 ipasha  staff       94 Aug 22 17:18 pydoc*
# -rwxr-xr-x  1 ipasha  staff      128 Aug 22 17:18 py.test*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 pttree*
# -rwxr-xr-x  1 ipasha  staff      160 Aug 22 17:18 ptrepack*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 ptdump*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 pt2to3*
# -rwxr-xr-x  1 ipasha  staff      109 Aug 22 17:18 idle*
# -rwxr-xr-x  1 ipasha  staff      111 Aug 22 17:18 2to3*
# lrwxr-xr-x  1 ipasha  staff       12 Aug 22 17:18 redis-sentinel@ -> redis-server
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 qttracereplay-qt4.app/
# -rw-r--r--  1 ipasha  staff      174 Aug 22 17:18 qt.conf
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 qhelpconverter-qt4.app/
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 pixeltool-qt4.app/
# -rwxr-xr-x  1 ipasha  staff      116 Aug 22 17:18 jupyter-qtconsole*
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 QMLViewer-qt4.app/
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 Linguist-qt4.app/
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 Designer-qt4.app/
# drwxr-xr-x  3 ipasha  staff      102 Aug 22 17:18 Assistant-qt4.app/
# -rwxr-xr-x  1 ipasha  staff      148 Aug 22 17:18 sphinx-quickstart*
# -rwxr-xr-x  1 ipasha  staff      126 Aug 22 17:18 sphinx-build*
# -rwxr-xr-x  1 ipasha  staff      176 Aug 22 17:18 sphinx-autogen*
# -rwxr-xr-x  1 ipasha  staff      140 Aug 22 17:18 sphinx-apidoc*
# -rwxr-xr-x  1 ipasha  staff      156 Aug 22 17:18 skivi*
# lrwxr-xr-x  1 ipasha  staff       12 Aug 22 17:18 easy_install-2.7@ -> easy_install
# -rwxr-xr-x  1 ipasha  staff      176 Aug 22 17:18 easy_install*
# -rwxr-xr-x  1 ipasha  staff       99 Aug 22 17:18 spyder*
# -rwxr-xr-x  1 ipasha  staff    11724 Aug 22 17:18 isympy*
# -rwxr-xr-x  1 ipasha  staff      154 Aug 22 17:18 xlwings*
# -rwxr-xr-x  1 ipasha  staff      134 Aug 22 17:18 wheel*
# -rwxr-xr-x  1 ipasha  staff     1971 Aug 22 17:18 vba_extract.py*
# lrwxr-xr-x  1 ipasha  staff        2 Aug 22 17:18 unxz@ -> xz
# -rwxr-xr-x  1 ipasha  staff    16319 Aug 22 17:18 runxlrd.py*
# -rw-r--r--  1 ipasha  staff    14406 Aug 22 17:32 Untitled.ipynb

# %%
cd /Users/ipasha/
# Out:
# /Users/ipasha

# %% [markdown]
# The "cd" command is how we navigate the filesystem and move between folders. It has several ways of taking your intended location. At all times, you can use the full path location, defined from the root directory of the system, to jump to another location. If you are trying to cd into a folder within your current directory you can use its name alone, i.e. "cd foldername". To move up in the directory structure one level at a time, we can use "cd .." (or, to go two up, "cd ../.." etc.).

# %%
mv hms.py hours-min-sec.py

# %% [markdown]
# The above command is an example of "move", and it is how we rename or move files within our directories. Here I have chosen to "move" hms.py to a new name, but in the same location. I could move and rename at the same time by appending the full path to the front of the new filename, i.e., "mv hms.py /Users/ipasha/documents/hms2.py"

# %%
cp hours-min-sec.py version2.py

# %% [markdown]
# The "cp" command is how we copy files. Here I copy a file into the same location, but in the same formatting as "mv" I could also specify a new path location. The first argument also can take a full path, if you are not already in the directory with the file.

# %% [markdown]
# A full list of useful UNIX commands with their options and common usages can be found on the Python Decal website, at http://ugastro.berkeley.edu/pydecal/unix_full.pdf . Additionally, the Python textbook found at http://ugastro.berkeley.edu/pydecal/textbook.pdf has the first chapter dedicated to UNIX. It is also a good resource for an overview of python in an astronomical context if these tutorials are speeding by too quickly for you.

# %% [markdown]
# ## Python

# %% [markdown]
# (For a more detailed introduction, see the texbook). Python is an open-source, high-level, freely available programming language. It has become the favored language of astronomers, and most new codes and programs are being written in it. So how do we do things with python? This crash course will skip over some of the fundamental basics to get to what you will need in this lab, that is, to read in data and use it. Note the import statements that will be required, but don't worry too much about why for now. We will cover this next week.

# %%
import numpy as np
import matplotlib.pyplot as plt
#making a fake dataset 

x_vals = np.arange(100) #make an array of x values [0,1,2,3,4,5,6,7,8...99]
y_vals = x_vals**2  #make y values that are the square of each x value [0,1,4,9,...]

data_array = [x_vals,y_vals] #put them into the same structure
data_array = np.transpose(data_array) #turn it into columns from ordered pairs
np.savetxt('filename.txt',data_array) #save it to a file

#Read it back in (this is one way to load your data - or any column based ascii file)

data_raw = np.genfromtxt('filename.txt') #loads the file name
data_raw = np.transpose(data_raw) # transposes from ordered pairs [[x1,y1],[x2,y2],...] into separate arrays by column [[x1,x2,...],[y1,y2,...]]

x = data_raw[0] #we use closed brackets to "index" lists, arrays, strings, etc., to pull the 0th, 1st, 2nd, etc elements.
y = data_raw[1]

# %%
#Let's plot the data

plt.plot(x,y,'ro',label='fake data') #many matplotlib shortcuts (some shown in textbook) - here "ro" means red circles
#some useful things we can do before viewing
plt.title('Informative title')
plt.xlabel('X-axis (units)')
plt.ylabel('Y-axis (units)')
plt.yscale('log') #what should a power-law dataset look like in log-log space?
plt.xscale('log')
#plt.xlim((low,high)) #would let us manually set the lower and upper end of the x axis values
#plt.ylim((low,high)) #same thing
plt.tight_layout() #reduce whitespace
plt.legend(loc=2) #show any specified "labels" from plotting in a legend, where loc=1,2,3,4 are the 4 corners of the graph. 
#Legend location, opacity, etc can all be fiddled with much more, this is the basic quick and dirty way. 

plt.show() #always needed to show the plot at the end.

# %% [markdown]
# This notebook, along with any we show, will be available on github at http://github.com/prappleizer/Astro120
